# %% [markdown]
# # Installing all the nessecary libaries and packages

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\ankit\appdata\local\continuum\anaconda3\lib\site-packages (3.4.5)
# Requirement already satisfied: six in c:\users\ankit\appdata\local\continuum\anaconda3\lib\site-packages (from nltk) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install GetOldTweets3
# Out:
# Collecting GetOldTweets3
#   Downloading https://files.pythonhosted.org/packages/ed/f4/a00c2a7c90801abc875325bb5416ce9090ac86d06a00cc887131bd73ba45/GetOldTweets3-0.0.11-py3-none-any.whl
# Collecting pyquery>=1.2.10 (from GetOldTweets3)
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=3.5.0 in c:\users\ankit\appdata\local\continuum\anaconda3\lib\site-packages (from GetOldTweets3) (4.4.1)
# Collecting cssselect>0.7.9 (from pyquery>=1.2.10->GetOldTweets3)
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 cssselect-1.1.0 pyquery-1.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download("punkt")
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ankit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ankit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import PorterStemmer,LancasterStemmer,SnowballStemmer
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt

# %%
def get_tweets():
    import GetOldTweets3 as got   # library used to scrape data from twitter without any other tools
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#corona') \
        .setSince("2020-03-01") \
        .setUntil("2020-03-30") \
        .setMaxTweets(500)
    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    # Creating list of chosen tweet data
    text_tweets = [[tweet.text] for tweet in tweets]
    return text_tweets

# %%
# Here i am fetching the data of march as the major outbreak of the disease took place in the month of march in India

# %%
# reading text file
# document=1
text = ""
text_tweets = get_tweets()

length = len(text_tweets)

for i in range(0, length):
    text = text_tweets[i][0] + " " + text

# converting to lowercase
lower_case = text.lower()

# Removing punctuations
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# splitting text into words
tokenized_words = word_tokenize(cleaned_text, "english")

# %%
text
# Out:
# 'Die #Flüchtlingspolitik ist gescheitert! Daher keine weitere Aufnahme. Und: Flüchtlinge in ein #Corona-Krisengebiet ausfliegen zu wollen ist Unsinn!  LOL on the lighter note #Pakistan #PakistanZindabad #Corona  New Yorkers To Be Fines Up To $500 If Told To Disperse, Keep Moving, Or Maintain Proper Distance * * * * #SocialDistancing #NYC #Corona #Coronavirus #COVID_19 #COVID19 #COVID_19 #COVID19USA #Quarantine #StayAware… https://www.instagram.com/p/B-Vfl7ThVnI/?igshid=b57xvwpdpnfw Loved stumbling upon this little message on my walk today. Stay healthy! #itsgoingtobealright #corona #lockdown2020 #selfisolation #quarantine #nyc #wewillgetthroughthis #stayinside #6feetapart #thankyounurses… https://www.instagram.com/p/B-VfqCtBuvO/?igshid=5mloztqgvhui Son dakika haberler… Bakan Selçuk: Huzurevleri için anlık http://rviv.ly/8robOU #covid #covid19 #corona #ankara #istanbul #kredi Nostaljik karantina http://rviv.ly/J1NgRF #covid #covid19 #corona #ankara #istanbul #kredi #adanifoundation #gautamadani #pmrelieffund #Respect #chinesevirus #corona https://www.instagram.com/p/B-VfqZmp-ER/?igshid=1ezcdqtr7e64u .@JesseLehrich #Trump\'s #Corona policy is unfair, risks the life of US citizens. US health system has some weak points; AcuteCareBeds/65y+population: KOR=rank 1, US 22, Italy 27 https://eiiw.wiwi.uni-wuppertal.de/fileadmin/eiiw/Daten/Publikationen/Gelbe_Reihe/jourMacroCvirus2020plus.pdf Will #corona’s antidot be found in Patalkot? #coronavirusindia Masker kain 2 lapis #corona #masker Hub. 082323822833 https://www.instagram.com/p/B-Vfs9lnPkm/?igshid=idpc5jjz10iq #Corona Testing for everyone in india is not required because most of the rural and poor population has never been in touch with Foreigners. Other countries have huge foreign travellers. Freunde, die Pandemie ist vorbei! Wir sind alle erlöst! Der Televangelist Kenneth Copeland hat Covid-19 verbal mal so richtig in den Virenpopo getreten! IT IS FINISHED! #Corona #coronavirus https://youtu.be/QJ6TlhXfTeU #corona #Covid_19 #corona https://www.instagram.com/p/B-Vft6fJwQm/?igshid=8fyssy4yotim This is the cure for the Corona!! I swear if I had it, it’s gone now! #corona #cure #mexican #cure https://www.instagram.com/p/B-VfuGWnYyf/?igshid=11wmvktdivnez Social distance, this limiting your trips away from home and fill up when it drops. #problemsolved #corona #gas Reposted from @manstagram__420 ( #memes #corona #memedaily #funnymemes #memesdaily #funnyshit | For more : https://funnyshit.fun ) Picking out my #Easter outfit this year... #covid #corona #CoronaVirus #Pajamas #Lockdown https://www.instagram.com/p/B-VfvwTpKPK/?igshid=wez12a5m764e It is needed by Easter you will ho how bad NYC is. This is not a hoax.. it is very early in the stage of spreading. NYC alone will have 500 deaths per day within 2 weeks #corona Trump\'tan skandal sözler! Ölüm sayısını 200.000\'e düşürebilirsek harika bir iş çıkarırız https://yeniahval.com/haber/trumptan-skandal-sozler-olum-sayisini-200000e-dusurebilirsek-harika-bir-is-cikaririz-h11436.html #DonaldTrump #DonaldJTrump #abd #usa #usacovid19 #Covid_19 #COVID19 #corona #coronavirus #saglik #CoronavirusPandemic Ver jornal pra passar raiva com o pior presidente e mais irresponsável que o Brasil já teve. #Fantastico #Corona #Desgoverno #Corona ne saray dinledi ne kraliçe, ne prens dinledi ne prenses, ne başbakan, ne zengin, ne fakir, ne doktor, ne sporcu, ne sanatçı, ne işçi ne emekçi, ne dinci. Genç yaşlı, büyük küçük, kısacası hiç kimseyi dinlemedi. Bence bu #korona SOSYALİST herkes eşit davranıyor...  Doğa bizlerden elbet öcünü alacaktı... #doğa #coronavirus #Corona #Covid_19 #CoronavirusPandemic #turkey #ItalyCoronavirus #ChineseVirus19 #usacovid19 #Covid19turkey #Covid19Out #CovidSpain #covid19italy #IranFightsCorona #StayAtHomeChallenge #StayAtHomeSaveLives Steps this week; neighborhood walks. #corona #nyc #socialdistance #walking #brooklyn @Brooklyn, New York https://www.instagram.com/p/B-VfzCBlQvD/?igshid=vb0k2xlfjey3 What @ArvindKejriwal did was ...

# %%
tokenized_words
# Out:
# ['video',
#  'mit',
#  'ovvorsitzendem',
#  'manfred',
#  'klasen',
#  'die',
#  'linke',
#  'sbburbach',
#  'zum',
#  'solidarischen',
#  'verhalten',
#  'in',
#  'der',
#  'coronakrise',
#  '2',
#  'meter',
#  'abstand',
#  'linke',
#  'covidー19',
#  'coronavirusde',
#  'burbach',
#  'saarbrücken',
#  'saarwiesen',
#  'regionalverband',
#  'die',
#  'flüchtlingspolitik',
#  'ist',
#  'gescheitert',
#  'daher',
#  'keine',
#  'weitere',
#  'aufnahme',
#  'und',
#  'flüchtlinge',
#  'in',
#  'ein',
#  'coronakrisengebiet',
#  'ausfliegen',
#  'zu',
#  'wollen',
#  'ist',
#  'unsinn',
#  'lol',
#  'on',
#  'the',
#  'lighter',
#  'note',
#  'pakistan',
#  'pakistanzindabad',
#  'corona',
#  'new',
#  'yorkers',
#  'to',
#  'be',
#  'fines',
#  'up',
#  'to',
#  '500',
#  'if',
#  'told',
#  'to',
#  'disperse',
#  'keep',
#  'moving',
#  'or',
#  'maintain',
#  'proper',
#  'distance',
#  'socialdistancing',
#  'nyc',
#  'corona',
#  'coronavirus',
#  'covid19',
#  'covid19',
#  'covid19',
#  'covid19usa',
#  'quarantine',
#  'stayaware…',
#  'httpswwwinstagramcompbvfl7thvniigshidb57xvwpdpnfw',
#  'loved',
#  'stumbling',
#  'upon',
#  'this',
#  'little',
#  'message',
#  'on',
#  'my',
#  'walk',
#  'today',
#  'stay',
#  'healthy',
#  'itsgoingtobealright',
#  'corona',
#  'lockdown2020',
#  'selfisolation',
#  'quarantine',
#  'nyc',
#  'wewillgetthroughthis',
#  'stayinside',
#  '6feetapart',
#  'thankyounurses…',
#  'httpswwwinstagramcompbvfqctbuvoigshid5mloztqgvhui',
#  'son',
#  'dakika',
#  'haberler…',
#  'bakan',
#  'selçuk',
#  'huzurevleri',
#  'için',
#  'anlık',
#  'httprvivly8robou',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'nostaljik',
#  'karantina',
#  'httprvivlyj1ngrf',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'adanifoundation',
#  'gautamadani',
#  'pmrelieffund',
#  'respect',
#  'chinesevirus',
#  'corona',
#  'httpswwwinstagramcompbvfqzmperigshid1ezcdqtr7e64u',
#  'jesselehrich',
#  'trumps',
#  'corona',
#  'policy',
#  'is',
#  'unfair',
#  'risks',
#  'the',
#  'life',
#  'of',
#  'us',
#  'citizens',
#  'us',
#  'health',
#  'system',
#  'has',
#  'some',
#  'weak',
#  'points',
#  'acutecarebeds65ypopulation',
#  'korrank',
#  '1',
#  'us',
#  '22',
#  'italy',
#  '27',
#  'httpseiiwwiwiuniwuppertaldefileadmineiiwdatenpublikationengelbereihejourmacrocvirus2020pluspdf',
#  'will',
#  'corona',
#  '’',
#  's',
#  'antidot',
#  'be',
#  'found',
#  'in',
#  'patalkot',
#  'coronavirusindia',
#  'masker',
#  'kain',
#  '2',
#  'lapis',
#  'corona',
#  'masker',
#  'hub',
#  '082323822833',
#  'httpswwwinstagramcompbvfs9lnpkmigshididpc5jjz10iq',
#  'corona',
#  'testing',
#  'for',
#  'everyone',
#  'in',
#  'india',
#  'is',
#  'not',
#  'required',
#  'because',
#  'most',
#  'of',
#  'the',
#  'rural',
#  'and',
#  'poor',
#  'population',
#  'has',
#  'never',
#  'been',
#  'in',
#  'touch',
#  'with',
#  'foreigners',
#  'other',
#  'countries',
#  'have',
#  'huge',
#  'foreign',
#  'travellers',
#  'freunde',
#  'die',
#  'pandemie',
#  'ist',
#  'vorbei',
#  'wir',
#  'sind',
#  'alle',
#  'erlöst',
#  'der',
#  'televangelist',
#  'kenneth',
#  'copeland',
#  'hat',
#  'covid19',
#  'verbal',
#  'mal',
#  'so',
#  'richtig',
#  'in',
#  'den',
#  'virenpopo',
#  'getreten',
#  'it',
#  'is',
#  'finished',
#  'corona',
#  'coronavirus',
#  'httpsyoutubeqj6tlhxfteu',
#  'corona',
#  'covid19',
#  'corona',
#  'httpswwwinstagramcompbvft6fjwqmigshid8fyssy4yotim',
#  'this',
#  'is',
#  'the',
#  'cure',
#  'for',
#  'the',
#  'corona',
#  'i',
#  'swear',
#  'if',
#  'i',
#  'had',
#  'it',
#  'it',
#  '’',
#  's',
#  'gone',
#  'now',
#  'corona',
#  'cure',
#  'mexican',
#  'cure',
#  'httpswwwinstagramcompbvfugwnyyfigshid11wmvktdivnez',
#  'social',
#  'distance',
#  'this',
#  'limiting',
#  'your',
#  'trips',
#  'away',
#  'from',
#  'home',
#  'and',
#  'fill',
#  'up',
#  'when',
#  'it',
#  'drops',
#  'problemsolved',
#  'corona',
#  'gas',
#  'reposted',
#  'from',
#  'manstagram420',
#  'memes',
#  'corona',
#  'memedaily',
#  'funnymemes',
#  'memesdaily',
#  'funnyshit',
#  'for',
#  'more',
#  'httpsfunnyshitfun',
#  'picking',
#  'out',
#  'my',
#  'easter',
#  'outfit',
#  'this',
#  'year',
#  'covid',
#  'corona',
#  'coronavirus',
#  'pajamas',
#  'lockdown',
#  'httpswwwinstagramcompbvfvwtpkpkigshidwez12a5m764e',
#  'it',
#  'is',
#  'needed',
#  'by',
#  'easter',
#  'you',
#  'will',
#  'ho',
#  'how',
#  'bad',
#  'nyc',
#  'is',
#  'this',
#  'is',
#  'not',
#  'a',
#  'hoax',
#  'it',
#  'is',
#  'very',
#  'early',
#  'in',
#  'the',
#  'stage',
#  'of',
#  'spreading',
#  'nyc',
#  'alone',
#  'will',
#  'have',
#  '500',
#  'deaths',
#  'per',
#  'day',
#  'within',
#  '2',
#  'weeks',
#  'corona',
#  'trumptan',
#  'skandal',
#  'sözler',
#  'ölüm',
#  'sayısını',
#  '200000e',
#  'düşürebilirsek',
#  'harika',
#  'bir',
#  'iş',
#  'çıkarırız',
#  'httpsyeniahvalcomhabertrumptanskandalsozlerolumsayisini200000edusurebilirsekharikabiriscikaririzh11436html',
#  'donaldtrump',
#  'donaldjtrump',
#  'abd',
#  'usa',
#  'usacovid19',
#  'covid19',
#  'covid19',
#  'corona',
#  'coronavirus',
#  'saglik',
#  'coronaviruspandemic',
#  'ver',
#  'jornal',
#  'pra',
#  'passar',
#  'raiva',
#  'com',
#  'o',
#  'pior',
#  'presidente',
#  'e',
#  'mais',
#  'irresponsável',
#  'que',
#  'o',
#  'brasil',
#  'já',
#  'teve',
#  'fantastico',
#  'corona',
#  'desgoverno',
#  'corona',
#  'ne',
#  'saray',
#  'dinledi',
#  'ne',
#  'kraliçe',
#  'ne',
#  'prens',
#  'dinledi',
#  'ne',
#  'prenses',
#  'ne',
#  'başbakan',
#  'ne',
#  'zengin',
#  'ne',
#  'fakir',
#  'ne',
#  'doktor',
#  'ne',
#  'sporcu',
#  'ne',
#  'sanatçı',
#  'ne',
#  'işçi',
#  'ne',
#  'emekçi',
#  'ne',
#  'dinci',
#  'genç',
#  'yaşlı',
#  'büyük',
#  'küçük',
#  'kısacası',
#  'hiç',
#  'kimseyi',
#  'dinlemedi',
#  'bence',
#  'bu',
#  'korona',
#  'sosyali̇st',
#  'herkes',
#  'eşit',
#  'davranıyor',
#  'doğa',
#  'bizlerden',
#  'elbet',
#  'öcünü',
#  'alacaktı',
#  'doğa',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'coronaviruspandemic',
#  'turkey',
#  'italycoronavirus',
#  'chinesevirus19',
#  'usacovid19',
#  'covid19turkey',
#  'covid19out',
#  'covidspain',
#  'covid19italy',
#  'iranfightscorona',
#  'stayathomechallenge',
#  'stayathomesavelives',
#  'steps',
#  'this',
#  'week',
#  'neighborhood',
#  'walks',
#  'corona',
#  'nyc',
#  'socialdistance',
#  'walking',
#  'brooklyn',
#  'brooklyn',
#  'new',
#  'york',
#  'httpswwwinstagramcompbvfzcblqvdigshidvb0k2xlfjey3',
#  'what',
#  'arvindkejriwal',
#  'did',
#  'was',
#  'with',
#  'the',
#  'clear',
#  'intention',
#  'of',
#  'risking',
#  'the',
#  'lives',
#  'of',
#  'people',
#  'residing',
#  'in',
#  'nda',
#  'led',
#  'govts',
#  'putting',
#  'up',
#  'amp',
#  'bihar',
#  'on',
#  'worst',
#  'risk',
#  'by',
#  'sending',
#  'lacs',
#  'of',
#  'people',
#  'was',
#  'to',
#  'discredit',
#  'amp',
#  'push',
#  'up',
#  'bihar',
#  'amp',
#  'ultimately',
#  'india',
#  'into',
#  'worst',
#  'corona',
#  'crisis',
#  '7',
#  'habits',
#  'you',
#  'need',
#  'to',
#  'start',
#  'right',
#  'now',
#  'if',
#  'you',
#  'suspect',
#  'someone',
#  'in',
#  'your',
#  'home',
#  'is',
#  'sick',
#  'httpsbitly3bvg15t',
#  'activerealty',
#  'actvre',
#  'corona',
#  'articles',
#  'realestate',
#  'home',
#  'habit',
#  'start',
#  'rightnow',
#  'suspect',
#  'someone',
#  'sick',
#  'no',
#  'temas',
#  'fearnot',
#  'corona',
#  'coronavirus',
#  'covid',
#  'covid19',
#  'covıd19',
#  'httpswwwinstagramcompbvf2cwfmgiigshidpyh4s4nrixan',
#  'mau',
#  'besoksenin',
#  'selasa',
#  'rabu',
#  'kamis',
#  'jumat',
#  'sabtu',
#  'minggu',
#  'rebahan',
#  'ya',
#  'rebahan',
#  'nganggur',
#  'ya',
#  'tetap',
#  'nganggur',
#  'corona',
#  'sudah',
#  'lama',
#  'nganggur',
#  'b',
#  'aja',
#  'begitu',
#  'kerja',
#  'hampir',
#  'sedunia',
#  'nganggur',
#  'corona',
#  'coronavirus',
#  'coronakrise',
#  'mundschutz',
#  'maske',
#  'maskeauf',
#  'verkehrtewelt',
#  'jij',
#  'kan',
#  'het',
#  'verschil',
#  'maken',
#  'samen',
#  'tegen',
#  'het',
#  'corona',
#  'virus',
#  'zo',
#  'spontaan',
#  'en',
#  'puur',
#  'beauvaned',
#  'deze',
#  'aandacht',
#  'is',
#  'super',
#  'en',
#  'dit',
#  'doe',
#  'je',
#  'goed',
#  'rtl4',
#  'beaublijftthuis',
#  'beaublijftbinnen',
#  'covid19',
#  'transplantatie',
#  'jamai',
#  'zo',
#  'herkenbaar',
#  'im',
#  'raising',
#  'money',
#  'to',
#  'help',
#  'my',
#  'family',
#  'survive',
#  'uncle',
#  'is',
#  'laid',
#  'off',
#  'me',
#  'and',
#  'my',
#  'aunt',
#  'are',
#  'disabled',
#  'need',
#  'help',
#  'with',
#  'grocery',
#  'and',
#  'bill',
#  'money',
#  'httpgfmeuxjvrn6',
#  'covid19',
#  'sundayvibes',
#  'corona',
#  'sundaythoughts',
#  'quarentinelife',
#  'help',
#  'stayathomeandstaysafe',
#  'lockdown',
#  'cashapp',
#  'pulte',
#  'on',
#  'the',
#  'q',
#  'why',
#  'in',
#  'the',
#  'usa',
#  'more',
#  'young',
#  'people',
#  'seem',
#  'to',
#  'die',
#  'of',
#  'corona',
#  'did',
#  'drbirx',
#  'really',
#  'say',
#  'that',
#  'the',
#  'population',
#  'of',
#  'the',
#  'usa',
#  'is',
#  '7',
#  'to',
#  '9',
#  'percent',
#  'younger',
#  'than',
#  'the',
#  'population',
#  'of',
#  'europe',
#  'maybe',
#  'drbirx',
#  'but',
#  'the',
#  'youth',
#  'of',
#  'the',
#  'usa',
#  'is',
#  'at',
#  'least',
#  '7',
#  'to',
#  '9',
#  'percent',
#  'more',
#  'obese',
#  'as',
#  'well',
#  'trumppressconf',
#  'xi',
#  'jinping',
#  '‘',
#  'itna',
#  'acche',
#  'se',
#  'corona',
#  'kaise',
#  'faila',
#  'diya',
#  'tumne',
#  '’',
#  'le',
#  'kejriwal',
#  'do',
#  'you',
#  'believe',
#  'that',
#  '100k',
#  'could',
#  'die',
#  'in',
#  'usa',
#  'a',
#  'yes',
#  'unconditionally',
#  'b',
#  'yes',
#  'with',
#  'my',
#  'head',
#  'no',
#  'with',
#  'my',
#  'heart',
#  'c',
#  'no',
#  'because',
#  'trump',
#  'd',
#  'no',
#  'its',
#  'a',
#  'liberaldem',
#  'hoax',
#  'from',
#  'china',
#  'cnnelection',
#  'cnntownhall',
#  'cnnsotu',
#  'cnn',
#  'nbc',
#  'abcnews',
#  'coronavirus',
#  'corona',
#  'coronavirus',
#  'coronacrisis',
#  'who',
#  'is',
#  'returning',
#  'toilet',
#  'paper',
#  'at',
#  'costco',
#  'lol',
#  'corona',
#  'humor',
#  'funnymemes',
#  'funnyshit',
#  'funnyquotes',
#  'costco',
#  'sandiego',
#  'san',
#  'httpswwwinstagramcompbvf7rqjnhvigshid36iecwwsfuq3',
#  'acoustic',
#  'live',
#  'music',
#  'from',
#  'quarantine',
#  'acousticguitar',
#  'acoustic',
#  'live',
#  'livestream',
#  'music',
#  'acousticmusic',
#  'looper',
#  'solo',
#  'guitarsolo',
#  'guitarist',
#  'singer',
#  'songwriter',
#  'musician',
#  'ditto',
#  'guitarplayer',
#  'corona…',
#  'httpswwwinstagramcompbvf3esjatmigshid16exgdle7j4of',
#  'probably',
#  'seemed',
#  'like',
#  'a',
#  'good',
#  'idea',
#  'in',
#  'theory',
#  'imagine',
#  'powerrangers',
#  'comedy',
#  'celebrities',
#  'covid19',
#  'corona',
#  'coronavirusmemes',
#  'quarantine',
#  'funnymemes',
#  'bebetter',
#  '“',
#  'no',
#  'one',
#  'calls',
#  'them',
#  'chicken',
#  'of',
#  'the',
#  'cave',
#  '”',
#  'anchorman',
#  'champ',
#  'fried',
#  'bat',
#  'corona',
#  'virus',
#  '2020',
#  'httpswwwinstagramcompbvf94glwvwigshidfsd6hrwcwg1',
#  'saurabhtop',
#  'sardesairajdeep',
#  'check',
#  'httpsflattenca',
#  'similar',
#  'self',
#  'assesment',
#  'tool',
#  'we',
#  'can',
#  'introduce',
#  'with',
#  'service',
#  'providers',
#  'reliancejio',
#  'airtelindia',
#  'vodafonein',
#  'in',
#  'india',
#  'this',
#  'concept',
#  'can',
#  'be',
#  'use',
#  'to',
#  'identify',
#  'and',
#  'track',
#  'corona',
#  'infected',
#  'people',
#  'in',
#  'community',
#  'indiafightscorona',
#  'nou',
#  'ja',
#  'ka',
#  'goumin',
#  'contre',
#  'en',
#  'virus',
#  'mais',
#  'fok',
#  'aussi',
#  'nou',
#  'goumin',
#  'contre',
#  'cochon',
#  'arrêter',
#  'un',
#  'peu',
#  'cestquoisa',
#  'corona',
#  'malpropre',
#  'httpswwwinstagramcompbvfox7ji4igshid1e8ke9u3raehd',
#  'i',
#  'think',
#  'we',
#  '’',
#  'll',
#  'see',
#  'aliens',
#  'visit',
#  'the',
#  'earth',
#  'next',
#  '2020',
#  'has',
#  'been',
#  'movie',
#  'genre',
#  'after',
#  'genre',
#  'after',
#  'genre',
#  'can',
#  'you',
#  'guess',
#  'the',
#  'ones',
#  'we',
#  '’',
#  've',
#  'already',
#  'had',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'corona',
#  'covid19',
#  'bazı',
#  'tavsiyeler',
#  'korona',
#  'bilmem',
#  'kaç',
#  'yüz',
#  'tane',
#  'hayvan',
#  'hücresi',
#  'boyutundadır',
#  'normal',
#  'virüslerden',
#  'oldukça',
#  'büyük',
#  'şişkoluğundan',
#  'dolayı',
#  'havada',
#  'fazlaca',
#  'asılı',
#  'kalamaz',
#  've',
#  'aşağı',
#  'düşer',
#  'bu',
#  'sebeple',
#  'dışarıdan',
#  'eve',
#  'geldiğinizde',
#  'ayakkabılarınızı',
#  'da',
#  'dezenfekte',
#  'etmenizi',
#  'öneririm',
#  'ahlak',
#  'namazı',
#  'bitene',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'riya',
#  'orucu',
#  'tutana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'tağşiş',
#  'malı',
#  'satana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'söze',
#  'yalan',
#  'katana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'haram',
#  'yerde',
#  'yatana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'yeğrenî',
#  ...]

# %%
length
# Out:
# 500

# %%
stop_words = stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Adding some more stop words in the list 
stop_words=["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
final_words = []

for word in tokenized_words:
    if word not in stop_words:
        final_words.append(word)

# %%
lemma_words = []

for word in final_words:
    word = WordNetLemmatizer().lemmatize(word)
    lemma_words.append(word)

# %%
emotion_list = []
with open('emotions.txt', 'r') as file:
    for line in file:
        clear_line = line.replace('\n', '').replace(',', '').replace("'", '').strip()
        word, emotion = clear_line.split(':')
        if word in lemma_words:
            emotion_list.append(emotion)
print("People emotions from the text \n", emotion_list, '\n \n')

w = Counter(emotion_list)
print("Count of each emotion \n", w)
# Out:
# People emotions from the text
#  [' cheated', ' attached', ' bored', ' safe', ' fearful', ' attracted', ' sad', ' embarrassed', ' free', ' happy', ' happy', ' attached', ' sad', ' angry', ' attracted', ' apathetic', ' happy', ' powerless', ' fearful', ' alone', ' attached', ' entitled', ' happy', ' loved', ' sad']
#
#
# Count of each emotion
#  Counter({' happy': 4, ' attached': 3, ' sad': 3, ' fearful': 2, ' attracted': 2, ' cheated': 1, ' bored': 1, ' safe': 1, ' embarrassed': 1, ' free': 1, ' angry': 1, ' apathetic': 1, ' powerless': 1, ' alone': 1, ' entitled': 1, ' loved': 1})

# %%
fig, ax1 = plt.subplots(figsize=(10,15))
ax1.bar(w.keys(), w.values())
fig.autofmt_xdate()
plt.savefig('graph.png')
plt.show()

# %%
def get_tweets():
    import GetOldTweets3 as got   # library used to scrape data from twitter without any other tools
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#covid19pandemic') \
        .setSince("2020-06-20") \
        .setUntil("2020-07-20") \
        .setMaxTweets(500)
    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    # Creating list of chosen tweet data
    text_tweets = [[tweet.text] for tweet in tweets]
    return text_tweets

# %%
# reading text file
# document=2
newtext = ""
newtext_tweets = get_tweets()

newlength = len(newtext_tweets)

for i in range(0, newlength):
    newtext = newtext_tweets[i][0] + " " + newtext

# converting to lowercase
newlower_case = newtext.lower()

# Removing punctuations
newcleaned_text = newlower_case.translate(str.maketrans('', '', string.punctuation))

# splitting text into words
newtokenized_words = word_tokenize(newcleaned_text, "english")

# %%
newtext
# Out:
# '#Video mit #OV-Vorsitzendem Manfred #Klasen, DIE LINKE. SB-Burbach, zum solidarischen Verhalten in der #Corona-Krise 2 Meter Abstand #Linke #COVIDー19 #CoronaVirusDE #Burbach #Saarbrücken #Saarwiesen #Regionalverband . Die #Flüchtlingspolitik ist gescheitert! Daher keine weitere Aufnahme. Und: Flüchtlinge in ein #Corona-Krisengebiet ausfliegen zu wollen ist Unsinn!  LOL on the lighter note #Pakistan #PakistanZindabad #Corona  New Yorkers To Be Fines Up To $500 If Told To Disperse, Keep Moving, Or Maintain Proper Distance * * * * #SocialDistancing #NYC #Corona #Coronavirus #COVID_19 #COVID19 #COVID_19 #COVID19USA #Quarantine #StayAware… https://www.instagram.com/p/B-Vfl7ThVnI/?igshid=b57xvwpdpnfw Loved stumbling upon this little message on my walk today. Stay healthy! #itsgoingtobealright #corona #lockdown2020 #selfisolation #quarantine #nyc #wewillgetthroughthis #stayinside #6feetapart #thankyounurses… https://www.instagram.com/p/B-VfqCtBuvO/?igshid=5mloztqgvhui Son dakika haberler… Bakan Selçuk: Huzurevleri için anlık http://rviv.ly/8robOU #covid #covid19 #corona #ankara #istanbul #kredi Nostaljik karantina http://rviv.ly/J1NgRF #covid #covid19 #corona #ankara #istanbul #kredi #adanifoundation #gautamadani #pmrelieffund #Respect #chinesevirus #corona https://www.instagram.com/p/B-VfqZmp-ER/?igshid=1ezcdqtr7e64u .@JesseLehrich #Trump\'s #Corona policy is unfair, risks the life of US citizens. US health system has some weak points; AcuteCareBeds/65y+population: KOR=rank 1, US 22, Italy 27 https://eiiw.wiwi.uni-wuppertal.de/fileadmin/eiiw/Daten/Publikationen/Gelbe_Reihe/jourMacroCvirus2020plus.pdf Will #corona’s antidot be found in Patalkot? #coronavirusindia Masker kain 2 lapis #corona #masker Hub. 082323822833 https://www.instagram.com/p/B-Vfs9lnPkm/?igshid=idpc5jjz10iq #Corona Testing for everyone in india is not required because most of the rural and poor population has never been in touch with Foreigners. Other countries have huge foreign travellers. Freunde, die Pandemie ist vorbei! Wir sind alle erlöst! Der Televangelist Kenneth Copeland hat Covid-19 verbal mal so richtig in den Virenpopo getreten! IT IS FINISHED! #Corona #coronavirus https://youtu.be/QJ6TlhXfTeU #corona #Covid_19 #corona https://www.instagram.com/p/B-Vft6fJwQm/?igshid=8fyssy4yotim This is the cure for the Corona!! I swear if I had it, it’s gone now! #corona #cure #mexican #cure https://www.instagram.com/p/B-VfuGWnYyf/?igshid=11wmvktdivnez Social distance, this limiting your trips away from home and fill up when it drops. #problemsolved #corona #gas Reposted from @manstagram__420 ( #memes #corona #memedaily #funnymemes #memesdaily #funnyshit | For more : https://funnyshit.fun ) Picking out my #Easter outfit this year... #covid #corona #CoronaVirus #Pajamas #Lockdown https://www.instagram.com/p/B-VfvwTpKPK/?igshid=wez12a5m764e It is needed by Easter you will ho how bad NYC is. This is not a hoax.. it is very early in the stage of spreading. NYC alone will have 500 deaths per day within 2 weeks #corona Trump\'tan skandal sözler! Ölüm sayısını 200.000\'e düşürebilirsek harika bir iş çıkarırız https://yeniahval.com/haber/trumptan-skandal-sozler-olum-sayisini-200000e-dusurebilirsek-harika-bir-is-cikaririz-h11436.html #DonaldTrump #DonaldJTrump #abd #usa #usacovid19 #Covid_19 #COVID19 #corona #coronavirus #saglik #CoronavirusPandemic Ver jornal pra passar raiva com o pior presidente e mais irresponsável que o Brasil já teve. #Fantastico #Corona #Desgoverno #Corona ne saray dinledi ne kraliçe, ne prens dinledi ne prenses, ne başbakan, ne zengin, ne fakir, ne doktor, ne sporcu, ne sanatçı, ne işçi ne emekçi, ne dinci. Genç yaşlı, büyük küçük, kısacası hiç kimseyi dinlemedi. Bence bu #korona SOSYALİST herkes eşit davranıyor...  Doğa bizlerden elbet öcünü alacaktı... #doğa #coronavirus #Corona #Covid_19 #CoronavirusPandemic #turkey #ItalyCoronavirus #ChineseVirus19 #usacovid19 #Covid19turkey #Covid19Out #CovidSpain #covid19italy #IranFightsCorona #StayAtHomeChallen ...

# %%
newtokenized_words
# Out:
# ['video',
#  'mit',
#  'ovvorsitzendem',
#  'manfred',
#  'klasen',
#  'die',
#  'linke',
#  'sbburbach',
#  'zum',
#  'solidarischen',
#  'verhalten',
#  'in',
#  'der',
#  'coronakrise',
#  '2',
#  'meter',
#  'abstand',
#  'linke',
#  'covidー19',
#  'coronavirusde',
#  'burbach',
#  'saarbrücken',
#  'saarwiesen',
#  'regionalverband',
#  'die',
#  'flüchtlingspolitik',
#  'ist',
#  'gescheitert',
#  'daher',
#  'keine',
#  'weitere',
#  'aufnahme',
#  'und',
#  'flüchtlinge',
#  'in',
#  'ein',
#  'coronakrisengebiet',
#  'ausfliegen',
#  'zu',
#  'wollen',
#  'ist',
#  'unsinn',
#  'lol',
#  'on',
#  'the',
#  'lighter',
#  'note',
#  'pakistan',
#  'pakistanzindabad',
#  'corona',
#  'new',
#  'yorkers',
#  'to',
#  'be',
#  'fines',
#  'up',
#  'to',
#  '500',
#  'if',
#  'told',
#  'to',
#  'disperse',
#  'keep',
#  'moving',
#  'or',
#  'maintain',
#  'proper',
#  'distance',
#  'socialdistancing',
#  'nyc',
#  'corona',
#  'coronavirus',
#  'covid19',
#  'covid19',
#  'covid19',
#  'covid19usa',
#  'quarantine',
#  'stayaware…',
#  'httpswwwinstagramcompbvfl7thvniigshidb57xvwpdpnfw',
#  'loved',
#  'stumbling',
#  'upon',
#  'this',
#  'little',
#  'message',
#  'on',
#  'my',
#  'walk',
#  'today',
#  'stay',
#  'healthy',
#  'itsgoingtobealright',
#  'corona',
#  'lockdown2020',
#  'selfisolation',
#  'quarantine',
#  'nyc',
#  'wewillgetthroughthis',
#  'stayinside',
#  '6feetapart',
#  'thankyounurses…',
#  'httpswwwinstagramcompbvfqctbuvoigshid5mloztqgvhui',
#  'son',
#  'dakika',
#  'haberler…',
#  'bakan',
#  'selçuk',
#  'huzurevleri',
#  'için',
#  'anlık',
#  'httprvivly8robou',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'nostaljik',
#  'karantina',
#  'httprvivlyj1ngrf',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'adanifoundation',
#  'gautamadani',
#  'pmrelieffund',
#  'respect',
#  'chinesevirus',
#  'corona',
#  'httpswwwinstagramcompbvfqzmperigshid1ezcdqtr7e64u',
#  'jesselehrich',
#  'trumps',
#  'corona',
#  'policy',
#  'is',
#  'unfair',
#  'risks',
#  'the',
#  'life',
#  'of',
#  'us',
#  'citizens',
#  'us',
#  'health',
#  'system',
#  'has',
#  'some',
#  'weak',
#  'points',
#  'acutecarebeds65ypopulation',
#  'korrank',
#  '1',
#  'us',
#  '22',
#  'italy',
#  '27',
#  'httpseiiwwiwiuniwuppertaldefileadmineiiwdatenpublikationengelbereihejourmacrocvirus2020pluspdf',
#  'will',
#  'corona',
#  '’',
#  's',
#  'antidot',
#  'be',
#  'found',
#  'in',
#  'patalkot',
#  'coronavirusindia',
#  'masker',
#  'kain',
#  '2',
#  'lapis',
#  'corona',
#  'masker',
#  'hub',
#  '082323822833',
#  'httpswwwinstagramcompbvfs9lnpkmigshididpc5jjz10iq',
#  'corona',
#  'testing',
#  'for',
#  'everyone',
#  'in',
#  'india',
#  'is',
#  'not',
#  'required',
#  'because',
#  'most',
#  'of',
#  'the',
#  'rural',
#  'and',
#  'poor',
#  'population',
#  'has',
#  'never',
#  'been',
#  'in',
#  'touch',
#  'with',
#  'foreigners',
#  'other',
#  'countries',
#  'have',
#  'huge',
#  'foreign',
#  'travellers',
#  'freunde',
#  'die',
#  'pandemie',
#  'ist',
#  'vorbei',
#  'wir',
#  'sind',
#  'alle',
#  'erlöst',
#  'der',
#  'televangelist',
#  'kenneth',
#  'copeland',
#  'hat',
#  'covid19',
#  'verbal',
#  'mal',
#  'so',
#  'richtig',
#  'in',
#  'den',
#  'virenpopo',
#  'getreten',
#  'it',
#  'is',
#  'finished',
#  'corona',
#  'coronavirus',
#  'httpsyoutubeqj6tlhxfteu',
#  'corona',
#  'covid19',
#  'corona',
#  'httpswwwinstagramcompbvft6fjwqmigshid8fyssy4yotim',
#  'this',
#  'is',
#  'the',
#  'cure',
#  'for',
#  'the',
#  'corona',
#  'i',
#  'swear',
#  'if',
#  'i',
#  'had',
#  'it',
#  'it',
#  '’',
#  's',
#  'gone',
#  'now',
#  'corona',
#  'cure',
#  'mexican',
#  'cure',
#  'httpswwwinstagramcompbvfugwnyyfigshid11wmvktdivnez',
#  'social',
#  'distance',
#  'this',
#  'limiting',
#  'your',
#  'trips',
#  'away',
#  'from',
#  'home',
#  'and',
#  'fill',
#  'up',
#  'when',
#  'it',
#  'drops',
#  'problemsolved',
#  'corona',
#  'gas',
#  'reposted',
#  'from',
#  'manstagram420',
#  'memes',
#  'corona',
#  'memedaily',
#  'funnymemes',
#  'memesdaily',
#  'funnyshit',
#  'for',
#  'more',
#  'httpsfunnyshitfun',
#  'picking',
#  'out',
#  'my',
#  'easter',
#  'outfit',
#  'this',
#  'year',
#  'covid',
#  'corona',
#  'coronavirus',
#  'pajamas',
#  'lockdown',
#  'httpswwwinstagramcompbvfvwtpkpkigshidwez12a5m764e',
#  'it',
#  'is',
#  'needed',
#  'by',
#  'easter',
#  'you',
#  'will',
#  'ho',
#  'how',
#  'bad',
#  'nyc',
#  'is',
#  'this',
#  'is',
#  'not',
#  'a',
#  'hoax',
#  'it',
#  'is',
#  'very',
#  'early',
#  'in',
#  'the',
#  'stage',
#  'of',
#  'spreading',
#  'nyc',
#  'alone',
#  'will',
#  'have',
#  '500',
#  'deaths',
#  'per',
#  'day',
#  'within',
#  '2',
#  'weeks',
#  'corona',
#  'trumptan',
#  'skandal',
#  'sözler',
#  'ölüm',
#  'sayısını',
#  '200000e',
#  'düşürebilirsek',
#  'harika',
#  'bir',
#  'iş',
#  'çıkarırız',
#  'httpsyeniahvalcomhabertrumptanskandalsozlerolumsayisini200000edusurebilirsekharikabiriscikaririzh11436html',
#  'donaldtrump',
#  'donaldjtrump',
#  'abd',
#  'usa',
#  'usacovid19',
#  'covid19',
#  'covid19',
#  'corona',
#  'coronavirus',
#  'saglik',
#  'coronaviruspandemic',
#  'ver',
#  'jornal',
#  'pra',
#  'passar',
#  'raiva',
#  'com',
#  'o',
#  'pior',
#  'presidente',
#  'e',
#  'mais',
#  'irresponsável',
#  'que',
#  'o',
#  'brasil',
#  'já',
#  'teve',
#  'fantastico',
#  'corona',
#  'desgoverno',
#  'corona',
#  'ne',
#  'saray',
#  'dinledi',
#  'ne',
#  'kraliçe',
#  'ne',
#  'prens',
#  'dinledi',
#  'ne',
#  'prenses',
#  'ne',
#  'başbakan',
#  'ne',
#  'zengin',
#  'ne',
#  'fakir',
#  'ne',
#  'doktor',
#  'ne',
#  'sporcu',
#  'ne',
#  'sanatçı',
#  'ne',
#  'işçi',
#  'ne',
#  'emekçi',
#  'ne',
#  'dinci',
#  'genç',
#  'yaşlı',
#  'büyük',
#  'küçük',
#  'kısacası',
#  'hiç',
#  'kimseyi',
#  'dinlemedi',
#  'bence',
#  'bu',
#  'korona',
#  'sosyali̇st',
#  'herkes',
#  'eşit',
#  'davranıyor',
#  'doğa',
#  'bizlerden',
#  'elbet',
#  'öcünü',
#  'alacaktı',
#  'doğa',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'coronaviruspandemic',
#  'turkey',
#  'italycoronavirus',
#  'chinesevirus19',
#  'usacovid19',
#  'covid19turkey',
#  'covid19out',
#  'covidspain',
#  'covid19italy',
#  'iranfightscorona',
#  'stayathomechallenge',
#  'stayathomesavelives',
#  'steps',
#  'this',
#  'week',
#  'neighborhood',
#  'walks',
#  'corona',
#  'nyc',
#  'socialdistance',
#  'walking',
#  'brooklyn',
#  'brooklyn',
#  'new',
#  'york',
#  'httpswwwinstagramcompbvfzcblqvdigshidvb0k2xlfjey3',
#  'what',
#  'arvindkejriwal',
#  'did',
#  'was',
#  'with',
#  'the',
#  'clear',
#  'intention',
#  'of',
#  'risking',
#  'the',
#  'lives',
#  'of',
#  'people',
#  'residing',
#  'in',
#  'nda',
#  'led',
#  'govts',
#  'putting',
#  'up',
#  'amp',
#  'bihar',
#  'on',
#  'worst',
#  'risk',
#  'by',
#  'sending',
#  'lacs',
#  'of',
#  'people',
#  'was',
#  'to',
#  'discredit',
#  'amp',
#  'push',
#  'up',
#  'bihar',
#  'amp',
#  'ultimately',
#  'india',
#  'into',
#  'worst',
#  'corona',
#  'crisis',
#  '7',
#  'habits',
#  'you',
#  'need',
#  'to',
#  'start',
#  'right',
#  'now',
#  'if',
#  'you',
#  'suspect',
#  'someone',
#  'in',
#  'your',
#  'home',
#  'is',
#  'sick',
#  'httpsbitly3bvg15t',
#  'activerealty',
#  'actvre',
#  'corona',
#  'articles',
#  'realestate',
#  'home',
#  'habit',
#  'start',
#  'rightnow',
#  'suspect',
#  'someone',
#  'sick',
#  'no',
#  'temas',
#  'fearnot',
#  'corona',
#  'coronavirus',
#  'covid',
#  'covid19',
#  'covıd19',
#  'httpswwwinstagramcompbvf2cwfmgiigshidpyh4s4nrixan',
#  'mau',
#  'besoksenin',
#  'selasa',
#  'rabu',
#  'kamis',
#  'jumat',
#  'sabtu',
#  'minggu',
#  'rebahan',
#  'ya',
#  'rebahan',
#  'nganggur',
#  'ya',
#  'tetap',
#  'nganggur',
#  'corona',
#  'sudah',
#  'lama',
#  'nganggur',
#  'b',
#  'aja',
#  'begitu',
#  'kerja',
#  'hampir',
#  'sedunia',
#  'nganggur',
#  'corona',
#  'coronavirus',
#  'coronakrise',
#  'mundschutz',
#  'maske',
#  'maskeauf',
#  'verkehrtewelt',
#  'jij',
#  'kan',
#  'het',
#  'verschil',
#  'maken',
#  'samen',
#  'tegen',
#  'het',
#  'corona',
#  'virus',
#  'zo',
#  'spontaan',
#  'en',
#  'puur',
#  'beauvaned',
#  'deze',
#  'aandacht',
#  'is',
#  'super',
#  'en',
#  'dit',
#  'doe',
#  'je',
#  'goed',
#  'rtl4',
#  'beaublijftthuis',
#  'beaublijftbinnen',
#  'covid19',
#  'transplantatie',
#  'jamai',
#  'zo',
#  'herkenbaar',
#  'im',
#  'raising',
#  'money',
#  'to',
#  'help',
#  'my',
#  'family',
#  'survive',
#  'uncle',
#  'is',
#  'laid',
#  'off',
#  'me',
#  'and',
#  'my',
#  'aunt',
#  'are',
#  'disabled',
#  'need',
#  'help',
#  'with',
#  'grocery',
#  'and',
#  'bill',
#  'money',
#  'httpgfmeuxjvrn6',
#  'covid19',
#  'sundayvibes',
#  'corona',
#  'sundaythoughts',
#  'quarentinelife',
#  'help',
#  'stayathomeandstaysafe',
#  'lockdown',
#  'cashapp',
#  'pulte',
#  'on',
#  'the',
#  'q',
#  'why',
#  'in',
#  'the',
#  'usa',
#  'more',
#  'young',
#  'people',
#  'seem',
#  'to',
#  'die',
#  'of',
#  'corona',
#  'did',
#  'drbirx',
#  'really',
#  'say',
#  'that',
#  'the',
#  'population',
#  'of',
#  'the',
#  'usa',
#  'is',
#  '7',
#  'to',
#  '9',
#  'percent',
#  'younger',
#  'than',
#  'the',
#  'population',
#  'of',
#  'europe',
#  'maybe',
#  'drbirx',
#  'but',
#  'the',
#  'youth',
#  'of',
#  'the',
#  'usa',
#  'is',
#  'at',
#  'least',
#  '7',
#  'to',
#  '9',
#  'percent',
#  'more',
#  'obese',
#  'as',
#  'well',
#  'trumppressconf',
#  'xi',
#  'jinping',
#  '‘',
#  'itna',
#  'acche',
#  'se',
#  'corona',
#  'kaise',
#  'faila',
#  'diya',
#  'tumne',
#  '’',
#  'le',
#  'kejriwal',
#  'do',
#  'you',
#  'believe',
#  'that',
#  '100k',
#  'could',
#  'die',
#  'in',
#  'usa',
#  'a',
#  'yes',
#  'unconditionally',
#  'b',
#  'yes',
#  'with',
#  'my',
#  'head',
#  'no',
#  'with',
#  'my',
#  'heart',
#  'c',
#  'no',
#  'because',
#  'trump',
#  'd',
#  'no',
#  'its',
#  'a',
#  'liberaldem',
#  'hoax',
#  'from',
#  'china',
#  'cnnelection',
#  'cnntownhall',
#  'cnnsotu',
#  'cnn',
#  'nbc',
#  'abcnews',
#  'coronavirus',
#  'corona',
#  'coronavirus',
#  'coronacrisis',
#  'who',
#  'is',
#  'returning',
#  'toilet',
#  'paper',
#  'at',
#  'costco',
#  'lol',
#  'corona',
#  'humor',
#  'funnymemes',
#  'funnyshit',
#  'funnyquotes',
#  'costco',
#  'sandiego',
#  'san',
#  'httpswwwinstagramcompbvf7rqjnhvigshid36iecwwsfuq3',
#  'acoustic',
#  'live',
#  'music',
#  'from',
#  'quarantine',
#  'acousticguitar',
#  'acoustic',
#  'live',
#  'livestream',
#  'music',
#  'acousticmusic',
#  'looper',
#  'solo',
#  'guitarsolo',
#  'guitarist',
#  'singer',
#  'songwriter',
#  'musician',
#  'ditto',
#  'guitarplayer',
#  'corona…',
#  'httpswwwinstagramcompbvf3esjatmigshid16exgdle7j4of',
#  'probably',
#  'seemed',
#  'like',
#  'a',
#  'good',
#  'idea',
#  'in',
#  'theory',
#  'imagine',
#  'powerrangers',
#  'comedy',
#  'celebrities',
#  'covid19',
#  'corona',
#  'coronavirusmemes',
#  'quarantine',
#  'funnymemes',
#  'bebetter',
#  '“',
#  'no',
#  'one',
#  'calls',
#  'them',
#  'chicken',
#  'of',
#  'the',
#  'cave',
#  '”',
#  'anchorman',
#  'champ',
#  'fried',
#  'bat',
#  'corona',
#  'virus',
#  '2020',
#  'httpswwwinstagramcompbvf94glwvwigshidfsd6hrwcwg1',
#  'saurabhtop',
#  'sardesairajdeep',
#  'check',
#  'httpsflattenca',
#  'similar',
#  'self',
#  'assesment',
#  'tool',
#  'we',
#  'can',
#  'introduce',
#  'with',
#  'service',
#  'providers',
#  'reliancejio',
#  'airtelindia',
#  'vodafonein',
#  'in',
#  'india',
#  'this',
#  'concept',
#  'can',
#  'be',
#  'use',
#  'to',
#  'identify',
#  'and',
#  'track',
#  'corona',
#  'infected',
#  'people',
#  'in',
#  'community',
#  'indiafightscorona',
#  'nou',
#  'ja',
#  'ka',
#  'goumin',
#  'contre',
#  'en',
#  'virus',
#  'mais',
#  'fok',
#  'aussi',
#  'nou',
#  'goumin',
#  'contre',
#  'cochon',
#  'arrêter',
#  'un',
#  'peu',
#  'cestquoisa',
#  'corona',
#  'malpropre',
#  'httpswwwinstagramcompbvfox7ji4igshid1e8ke9u3raehd',
#  'i',
#  'think',
#  'we',
#  '’',
#  'll',
#  'see',
#  'aliens',
#  'visit',
#  'the',
#  'earth',
#  'next',
#  '2020',
#  'has',
#  'been',
#  'movie',
#  'genre',
#  'after',
#  'genre',
#  'after',
#  'genre',
#  'can',
#  'you',
#  'guess',
#  'the',
#  'ones',
#  'we',
#  '’',
#  've',
#  'already',
#  'had',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'corona',
#  'covid19',
#  'bazı',
#  'tavsiyeler',
#  'korona',
#  'bilmem',
#  'kaç',
#  'yüz',
#  'tane',
#  'hayvan',
#  'hücresi',
#  'boyutundadır',
#  'normal',
#  'virüslerden',
#  'oldukça',
#  'büyük',
#  'şişkoluğundan',
#  'dolayı',
#  'havada',
#  'fazlaca',
#  'asılı',
#  'kalamaz',
#  've',
#  'aşağı',
#  'düşer',
#  'bu',
#  'sebeple',
#  'dışarıdan',
#  'eve',
#  'geldiğinizde',
#  'ayakkabılarınızı',
#  'da',
#  'dezenfekte',
#  'etmenizi',
#  'öneririm',
#  'ahlak',
#  'namazı',
#  'bitene',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'riya',
#  'orucu',
#  'tutana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'tağşiş',
#  'malı',
#  'satana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'söze',
#  'yalan',
#  'katana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'haram',
#  'yerde',
#  'yatana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'yeğrenî',
#  ...]

# %%
newfinal_words = []

for word in newtokenized_words:
    if word not in stop_words:
        newfinal_words.append(word)

# %%
newfinal_words
# Out:
# ['video',
#  'mit',
#  'ovvorsitzendem',
#  'manfred',
#  'klasen',
#  'die',
#  'linke',
#  'sbburbach',
#  'zum',
#  'solidarischen',
#  'verhalten',
#  'der',
#  'coronakrise',
#  '2',
#  'meter',
#  'abstand',
#  'linke',
#  'covidー19',
#  'coronavirusde',
#  'burbach',
#  'saarbrücken',
#  'saarwiesen',
#  'regionalverband',
#  'die',
#  'flüchtlingspolitik',
#  'ist',
#  'gescheitert',
#  'daher',
#  'keine',
#  'weitere',
#  'aufnahme',
#  'und',
#  'flüchtlinge',
#  'ein',
#  'coronakrisengebiet',
#  'ausfliegen',
#  'zu',
#  'wollen',
#  'ist',
#  'unsinn',
#  'lol',
#  'lighter',
#  'note',
#  'pakistan',
#  'pakistanzindabad',
#  'corona',
#  'new',
#  'yorkers',
#  'fines',
#  '500',
#  'told',
#  'disperse',
#  'keep',
#  'moving',
#  'maintain',
#  'proper',
#  'distance',
#  'socialdistancing',
#  'nyc',
#  'corona',
#  'coronavirus',
#  'covid19',
#  'covid19',
#  'covid19',
#  'covid19usa',
#  'quarantine',
#  'stayaware…',
#  'httpswwwinstagramcompbvfl7thvniigshidb57xvwpdpnfw',
#  'loved',
#  'stumbling',
#  'upon',
#  'little',
#  'message',
#  'walk',
#  'today',
#  'stay',
#  'healthy',
#  'itsgoingtobealright',
#  'corona',
#  'lockdown2020',
#  'selfisolation',
#  'quarantine',
#  'nyc',
#  'wewillgetthroughthis',
#  'stayinside',
#  '6feetapart',
#  'thankyounurses…',
#  'httpswwwinstagramcompbvfqctbuvoigshid5mloztqgvhui',
#  'son',
#  'dakika',
#  'haberler…',
#  'bakan',
#  'selçuk',
#  'huzurevleri',
#  'için',
#  'anlık',
#  'httprvivly8robou',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'nostaljik',
#  'karantina',
#  'httprvivlyj1ngrf',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'adanifoundation',
#  'gautamadani',
#  'pmrelieffund',
#  'respect',
#  'chinesevirus',
#  'corona',
#  'httpswwwinstagramcompbvfqzmperigshid1ezcdqtr7e64u',
#  'jesselehrich',
#  'trumps',
#  'corona',
#  'policy',
#  'unfair',
#  'risks',
#  'life',
#  'us',
#  'citizens',
#  'us',
#  'health',
#  'system',
#  'weak',
#  'points',
#  'acutecarebeds65ypopulation',
#  'korrank',
#  '1',
#  'us',
#  '22',
#  'italy',
#  '27',
#  'httpseiiwwiwiuniwuppertaldefileadmineiiwdatenpublikationengelbereihejourmacrocvirus2020pluspdf',
#  'corona',
#  '’',
#  'antidot',
#  'found',
#  'patalkot',
#  'coronavirusindia',
#  'masker',
#  'kain',
#  '2',
#  'lapis',
#  'corona',
#  'masker',
#  'hub',
#  '082323822833',
#  'httpswwwinstagramcompbvfs9lnpkmigshididpc5jjz10iq',
#  'corona',
#  'testing',
#  'everyone',
#  'india',
#  'required',
#  'rural',
#  'poor',
#  'population',
#  'never',
#  'touch',
#  'foreigners',
#  'countries',
#  'huge',
#  'foreign',
#  'travellers',
#  'freunde',
#  'die',
#  'pandemie',
#  'ist',
#  'vorbei',
#  'wir',
#  'sind',
#  'alle',
#  'erlöst',
#  'der',
#  'televangelist',
#  'kenneth',
#  'copeland',
#  'hat',
#  'covid19',
#  'verbal',
#  'mal',
#  'richtig',
#  'den',
#  'virenpopo',
#  'getreten',
#  'finished',
#  'corona',
#  'coronavirus',
#  'httpsyoutubeqj6tlhxfteu',
#  'corona',
#  'covid19',
#  'corona',
#  'httpswwwinstagramcompbvft6fjwqmigshid8fyssy4yotim',
#  'cure',
#  'corona',
#  'swear',
#  '’',
#  'gone',
#  'corona',
#  'cure',
#  'mexican',
#  'cure',
#  'httpswwwinstagramcompbvfugwnyyfigshid11wmvktdivnez',
#  'social',
#  'distance',
#  'limiting',
#  'trips',
#  'away',
#  'home',
#  'fill',
#  'drops',
#  'problemsolved',
#  'corona',
#  'gas',
#  'reposted',
#  'manstagram420',
#  'memes',
#  'corona',
#  'memedaily',
#  'funnymemes',
#  'memesdaily',
#  'funnyshit',
#  'httpsfunnyshitfun',
#  'picking',
#  'easter',
#  'outfit',
#  'year',
#  'covid',
#  'corona',
#  'coronavirus',
#  'pajamas',
#  'lockdown',
#  'httpswwwinstagramcompbvfvwtpkpkigshidwez12a5m764e',
#  'needed',
#  'easter',
#  'ho',
#  'bad',
#  'nyc',
#  'hoax',
#  'early',
#  'stage',
#  'spreading',
#  'nyc',
#  'alone',
#  '500',
#  'deaths',
#  'per',
#  'day',
#  'within',
#  '2',
#  'weeks',
#  'corona',
#  'trumptan',
#  'skandal',
#  'sözler',
#  'ölüm',
#  'sayısını',
#  '200000e',
#  'düşürebilirsek',
#  'harika',
#  'bir',
#  'iş',
#  'çıkarırız',
#  'httpsyeniahvalcomhabertrumptanskandalsozlerolumsayisini200000edusurebilirsekharikabiriscikaririzh11436html',
#  'donaldtrump',
#  'donaldjtrump',
#  'abd',
#  'usa',
#  'usacovid19',
#  'covid19',
#  'covid19',
#  'corona',
#  'coronavirus',
#  'saglik',
#  'coronaviruspandemic',
#  'ver',
#  'jornal',
#  'pra',
#  'passar',
#  'raiva',
#  'com',
#  'o',
#  'pior',
#  'presidente',
#  'e',
#  'mais',
#  'irresponsável',
#  'que',
#  'o',
#  'brasil',
#  'já',
#  'teve',
#  'fantastico',
#  'corona',
#  'desgoverno',
#  'corona',
#  'ne',
#  'saray',
#  'dinledi',
#  'ne',
#  'kraliçe',
#  'ne',
#  'prens',
#  'dinledi',
#  'ne',
#  'prenses',
#  'ne',
#  'başbakan',
#  'ne',
#  'zengin',
#  'ne',
#  'fakir',
#  'ne',
#  'doktor',
#  'ne',
#  'sporcu',
#  'ne',
#  'sanatçı',
#  'ne',
#  'işçi',
#  'ne',
#  'emekçi',
#  'ne',
#  'dinci',
#  'genç',
#  'yaşlı',
#  'büyük',
#  'küçük',
#  'kısacası',
#  'hiç',
#  'kimseyi',
#  'dinlemedi',
#  'bence',
#  'bu',
#  'korona',
#  'sosyali̇st',
#  'herkes',
#  'eşit',
#  'davranıyor',
#  'doğa',
#  'bizlerden',
#  'elbet',
#  'öcünü',
#  'alacaktı',
#  'doğa',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'coronaviruspandemic',
#  'turkey',
#  'italycoronavirus',
#  'chinesevirus19',
#  'usacovid19',
#  'covid19turkey',
#  'covid19out',
#  'covidspain',
#  'covid19italy',
#  'iranfightscorona',
#  'stayathomechallenge',
#  'stayathomesavelives',
#  'steps',
#  'week',
#  'neighborhood',
#  'walks',
#  'corona',
#  'nyc',
#  'socialdistance',
#  'walking',
#  'brooklyn',
#  'brooklyn',
#  'new',
#  'york',
#  'httpswwwinstagramcompbvfzcblqvdigshidvb0k2xlfjey3',
#  'arvindkejriwal',
#  'clear',
#  'intention',
#  'risking',
#  'lives',
#  'people',
#  'residing',
#  'nda',
#  'led',
#  'govts',
#  'putting',
#  'amp',
#  'bihar',
#  'worst',
#  'risk',
#  'sending',
#  'lacs',
#  'people',
#  'discredit',
#  'amp',
#  'push',
#  'bihar',
#  'amp',
#  'ultimately',
#  'india',
#  'worst',
#  'corona',
#  'crisis',
#  '7',
#  'habits',
#  'need',
#  'start',
#  'right',
#  'suspect',
#  'someone',
#  'home',
#  'sick',
#  'httpsbitly3bvg15t',
#  'activerealty',
#  'actvre',
#  'corona',
#  'articles',
#  'realestate',
#  'home',
#  'habit',
#  'start',
#  'rightnow',
#  'suspect',
#  'someone',
#  'sick',
#  'temas',
#  'fearnot',
#  'corona',
#  'coronavirus',
#  'covid',
#  'covid19',
#  'covıd19',
#  'httpswwwinstagramcompbvf2cwfmgiigshidpyh4s4nrixan',
#  'mau',
#  'besoksenin',
#  'selasa',
#  'rabu',
#  'kamis',
#  'jumat',
#  'sabtu',
#  'minggu',
#  'rebahan',
#  'ya',
#  'rebahan',
#  'nganggur',
#  'ya',
#  'tetap',
#  'nganggur',
#  'corona',
#  'sudah',
#  'lama',
#  'nganggur',
#  'b',
#  'aja',
#  'begitu',
#  'kerja',
#  'hampir',
#  'sedunia',
#  'nganggur',
#  'corona',
#  'coronavirus',
#  'coronakrise',
#  'mundschutz',
#  'maske',
#  'maskeauf',
#  'verkehrtewelt',
#  'jij',
#  'kan',
#  'het',
#  'verschil',
#  'maken',
#  'samen',
#  'tegen',
#  'het',
#  'corona',
#  'virus',
#  'zo',
#  'spontaan',
#  'en',
#  'puur',
#  'beauvaned',
#  'deze',
#  'aandacht',
#  'super',
#  'en',
#  'dit',
#  'doe',
#  'je',
#  'goed',
#  'rtl4',
#  'beaublijftthuis',
#  'beaublijftbinnen',
#  'covid19',
#  'transplantatie',
#  'jamai',
#  'zo',
#  'herkenbaar',
#  'im',
#  'raising',
#  'money',
#  'help',
#  'family',
#  'survive',
#  'uncle',
#  'laid',
#  'aunt',
#  'disabled',
#  'need',
#  'help',
#  'grocery',
#  'bill',
#  'money',
#  'httpgfmeuxjvrn6',
#  'covid19',
#  'sundayvibes',
#  'corona',
#  'sundaythoughts',
#  'quarentinelife',
#  'help',
#  'stayathomeandstaysafe',
#  'lockdown',
#  'cashapp',
#  'pulte',
#  'q',
#  'usa',
#  'young',
#  'people',
#  'seem',
#  'die',
#  'corona',
#  'drbirx',
#  'really',
#  'say',
#  'population',
#  'usa',
#  '7',
#  '9',
#  'percent',
#  'younger',
#  'population',
#  'europe',
#  'maybe',
#  'drbirx',
#  'youth',
#  'usa',
#  'least',
#  '7',
#  '9',
#  'percent',
#  'obese',
#  'well',
#  'trumppressconf',
#  'xi',
#  'jinping',
#  '‘',
#  'itna',
#  'acche',
#  'se',
#  'corona',
#  'kaise',
#  'faila',
#  'diya',
#  'tumne',
#  '’',
#  'le',
#  'kejriwal',
#  'believe',
#  '100k',
#  'could',
#  'die',
#  'usa',
#  'yes',
#  'unconditionally',
#  'b',
#  'yes',
#  'head',
#  'heart',
#  'c',
#  'trump',
#  'd',
#  'liberaldem',
#  'hoax',
#  'china',
#  'cnnelection',
#  'cnntownhall',
#  'cnnsotu',
#  'cnn',
#  'nbc',
#  'abcnews',
#  'coronavirus',
#  'corona',
#  'coronavirus',
#  'coronacrisis',
#  'returning',
#  'toilet',
#  'paper',
#  'costco',
#  'lol',
#  'corona',
#  'humor',
#  'funnymemes',
#  'funnyshit',
#  'funnyquotes',
#  'costco',
#  'sandiego',
#  'san',
#  'httpswwwinstagramcompbvf7rqjnhvigshid36iecwwsfuq3',
#  'acoustic',
#  'live',
#  'music',
#  'quarantine',
#  'acousticguitar',
#  'acoustic',
#  'live',
#  'livestream',
#  'music',
#  'acousticmusic',
#  'looper',
#  'solo',
#  'guitarsolo',
#  'guitarist',
#  'singer',
#  'songwriter',
#  'musician',
#  'ditto',
#  'guitarplayer',
#  'corona…',
#  'httpswwwinstagramcompbvf3esjatmigshid16exgdle7j4of',
#  'probably',
#  'seemed',
#  'like',
#  'good',
#  'idea',
#  'theory',
#  'imagine',
#  'powerrangers',
#  'comedy',
#  'celebrities',
#  'covid19',
#  'corona',
#  'coronavirusmemes',
#  'quarantine',
#  'funnymemes',
#  'bebetter',
#  '“',
#  'one',
#  'calls',
#  'chicken',
#  'cave',
#  '”',
#  'anchorman',
#  'champ',
#  'fried',
#  'bat',
#  'corona',
#  'virus',
#  '2020',
#  'httpswwwinstagramcompbvf94glwvwigshidfsd6hrwcwg1',
#  'saurabhtop',
#  'sardesairajdeep',
#  'check',
#  'httpsflattenca',
#  'similar',
#  'self',
#  'assesment',
#  'tool',
#  'introduce',
#  'service',
#  'providers',
#  'reliancejio',
#  'airtelindia',
#  'vodafonein',
#  'india',
#  'concept',
#  'use',
#  'identify',
#  'track',
#  'corona',
#  'infected',
#  'people',
#  'community',
#  'indiafightscorona',
#  'nou',
#  'ja',
#  'ka',
#  'goumin',
#  'contre',
#  'en',
#  'virus',
#  'mais',
#  'fok',
#  'aussi',
#  'nou',
#  'goumin',
#  'contre',
#  'cochon',
#  'arrêter',
#  'un',
#  'peu',
#  'cestquoisa',
#  'corona',
#  'malpropre',
#  'httpswwwinstagramcompbvfox7ji4igshid1e8ke9u3raehd',
#  'think',
#  '’',
#  'll',
#  'see',
#  'aliens',
#  'visit',
#  'earth',
#  'next',
#  '2020',
#  'movie',
#  'genre',
#  'genre',
#  'genre',
#  'guess',
#  'ones',
#  '’',
#  've',
#  'already',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'corona',
#  'covid19',
#  'bazı',
#  'tavsiyeler',
#  'korona',
#  'bilmem',
#  'kaç',
#  'yüz',
#  'tane',
#  'hayvan',
#  'hücresi',
#  'boyutundadır',
#  'normal',
#  'virüslerden',
#  'oldukça',
#  'büyük',
#  'şişkoluğundan',
#  'dolayı',
#  'havada',
#  'fazlaca',
#  'asılı',
#  'kalamaz',
#  've',
#  'aşağı',
#  'düşer',
#  'bu',
#  'sebeple',
#  'dışarıdan',
#  'eve',
#  'geldiğinizde',
#  'ayakkabılarınızı',
#  'da',
#  'dezenfekte',
#  'etmenizi',
#  'öneririm',
#  'ahlak',
#  'namazı',
#  'bitene',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'riya',
#  'orucu',
#  'tutana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'tağşiş',
#  'malı',
#  'satana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'söze',
#  'yalan',
#  'katana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'haram',
#  'yerde',
#  'yatana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'yeğrenî',
#  'kul',
#  'böyle',
#  'der',
#  'i̇nanmazsan',
#  'sor',
#  'ona',
#  'keine',
#  'macht',
#  'den',
#  'dilettanten',
#  'gut',
#  'dass',
#  'die',
#  'bundesregierung',
#  'auf',
#  'drosten',
#  'kekulé',
#  'und',
#  'andere',
#  'wahre',
#  'experten',
#  'hört',
#  'ökotyrannei',
#  'covid19',
#  'corona',
#  'repost',
#  'cantarafoundation',
#  '•',
#  '•',
#  '•',
#  '•',
#  '•',
#  'stayhome',
#  'dengan',
#  'dirumahaja',
#  'kita',
#  'sudah',
#  'berkontribusi',
#  'untuk',
#  'memutus',
#  'mata',
#  'rantai',
#  'penyebaran',
#  'virus',
#  'corona',
#  'covid19',
#  'dirumahaja',
#  'corona',
#  'virus…',
#  'httpswwwinstagramcompbvge2jaqsfjbrobscsq5equfugcpu7cvo0igshidvasfzm3bi2e4',
#  'bodycon',
#  'mesh',
#  'dress',
#  'httpswwwwestoutfitcomshopbodyconmeshdress',
#  'westoutfit',
#  'dresses',
#  'dress',
#  '20',
#  'free',
#  'ship',
#  'returns',
#  'covid',
#  'sale',
#  'girl',
#  'girls',
#  'gurl',
#  'women',
#  'womendress',
#  'usa',
#  'world',
#  'corona',
#  'dressstore',
#  'shopping',
#  'rough',
#  'quarantine',
#  'eat',
#  'freezer',
#  'grilling',
#  'quarantine',
#  'covid19',
#  'corona',
#  'httpswwwinstagramcompbvgf2hpehyigshid1hz8zlajlot13',
#  'httpsyenicizgihabercomhaberabdicinkorkutansenaryohaberi143951html',
#  'vaka9217',
#  'amerika',
#  'korona',
#  'corona',
#  'usa',
#  'covid19turkey',
#  'sondakika',
#  'haber',
#  'people',
#  'put',
#  'quarantine',
#  'italy',
#  'broke',
#  'outfast',
#  'foward',
#  'weeks',
#  'later',
#  'italy',
#  'tops',
#  'worlds',
#  'death',
#  'toll',
#  'people',
#  'eldoret',
#  'defied',
#  'stay',
#  'home',
#  'order',
#  '1',
#  'death',
#  'already',
#  'kenyans',
#  'still',
#  'dont',
#  'take',
#  'corona',
#  'seriously',
#  'smh',
#  'things',
#  'get',
#  'better',
#  'covid19',
#  'corona',
#  'httpwwwbenefitmankindcouk',
#  'stayathomeandstaysafe',
#  'new',
#  'podcast',
#  'café',
#  'com',
#  'rocknroll',
#  'spreaker',
#  'carreiraprofissional',
#  'corona',
#  'economia',
#  'empreendedorismo',
#  'voce',
#  'lockdown',
#  '’',
#  'important',
#  'remember',
#  'local',
#  'small',
#  'businesses',
#  'whether',
#  '’',
#  'coffee',
#  'shop',
#  'restaurant',
#  'bookstore',
#  'encourage',
#  'look',
#  'drive',
#  'options',
#  'area',
#  'support',
#  'small',
#  'business',
#  'smallbuisnesssunday',
#  'corona',
#  'supportsmallbusiness',
#  'dünyanın',
#  'kötü',
#  'bir',
#  'yer',
#  'olduğunu',
#  'söyler',
#  'dururduk',
#  'şimdi',
#  'o',
#  'kötü',
#  'dünyaya',
#  'muhtacız',
#  'corona',
#  'escape',
#  'new',
#  'york',
#  'shelter',
#  'place',
#  'nh',
#  'live',
#  'free',
#  '’',
#  'die',
#  'corona',
#  'covid19',
#  'escapefromnewyork',
#  'livefreeanddontdie',
#  'amherstnh',
#  'amherst',
#  'new',
#  'hampshire',
#  'httpswwwinstagramcompbvfoi2adczigshid1amv9c46mbui6',
#  'günlük',
#  'burç',
#  'yorumları',
#  '28',
#  'mart',
#  ...]

# %%
newlemma_words = []

for word in newfinal_words:
    word = WordNetLemmatizer().lemmatize(word)
    newlemma_words.append(word)

# %%
newlemma_words
# Out:
# ['video',
#  'mit',
#  'ovvorsitzendem',
#  'manfred',
#  'klasen',
#  'die',
#  'linke',
#  'sbburbach',
#  'zum',
#  'solidarischen',
#  'verhalten',
#  'der',
#  'coronakrise',
#  '2',
#  'meter',
#  'abstand',
#  'linke',
#  'covidー19',
#  'coronavirusde',
#  'burbach',
#  'saarbrücken',
#  'saarwiesen',
#  'regionalverband',
#  'die',
#  'flüchtlingspolitik',
#  'ist',
#  'gescheitert',
#  'daher',
#  'keine',
#  'weitere',
#  'aufnahme',
#  'und',
#  'flüchtlinge',
#  'ein',
#  'coronakrisengebiet',
#  'ausfliegen',
#  'zu',
#  'wollen',
#  'ist',
#  'unsinn',
#  'lol',
#  'lighter',
#  'note',
#  'pakistan',
#  'pakistanzindabad',
#  'corona',
#  'new',
#  'yorkers',
#  'fine',
#  '500',
#  'told',
#  'disperse',
#  'keep',
#  'moving',
#  'maintain',
#  'proper',
#  'distance',
#  'socialdistancing',
#  'nyc',
#  'corona',
#  'coronavirus',
#  'covid19',
#  'covid19',
#  'covid19',
#  'covid19usa',
#  'quarantine',
#  'stayaware…',
#  'httpswwwinstagramcompbvfl7thvniigshidb57xvwpdpnfw',
#  'loved',
#  'stumbling',
#  'upon',
#  'little',
#  'message',
#  'walk',
#  'today',
#  'stay',
#  'healthy',
#  'itsgoingtobealright',
#  'corona',
#  'lockdown2020',
#  'selfisolation',
#  'quarantine',
#  'nyc',
#  'wewillgetthroughthis',
#  'stayinside',
#  '6feetapart',
#  'thankyounurses…',
#  'httpswwwinstagramcompbvfqctbuvoigshid5mloztqgvhui',
#  'son',
#  'dakika',
#  'haberler…',
#  'bakan',
#  'selçuk',
#  'huzurevleri',
#  'için',
#  'anlık',
#  'httprvivly8robou',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'nostaljik',
#  'karantina',
#  'httprvivlyj1ngrf',
#  'covid',
#  'covid19',
#  'corona',
#  'ankara',
#  'istanbul',
#  'kredi',
#  'adanifoundation',
#  'gautamadani',
#  'pmrelieffund',
#  'respect',
#  'chinesevirus',
#  'corona',
#  'httpswwwinstagramcompbvfqzmperigshid1ezcdqtr7e64u',
#  'jesselehrich',
#  'trump',
#  'corona',
#  'policy',
#  'unfair',
#  'risk',
#  'life',
#  'u',
#  'citizen',
#  'u',
#  'health',
#  'system',
#  'weak',
#  'point',
#  'acutecarebeds65ypopulation',
#  'korrank',
#  '1',
#  'u',
#  '22',
#  'italy',
#  '27',
#  'httpseiiwwiwiuniwuppertaldefileadmineiiwdatenpublikationengelbereihejourmacrocvirus2020pluspdf',
#  'corona',
#  '’',
#  'antidot',
#  'found',
#  'patalkot',
#  'coronavirusindia',
#  'masker',
#  'kain',
#  '2',
#  'lapis',
#  'corona',
#  'masker',
#  'hub',
#  '082323822833',
#  'httpswwwinstagramcompbvfs9lnpkmigshididpc5jjz10iq',
#  'corona',
#  'testing',
#  'everyone',
#  'india',
#  'required',
#  'rural',
#  'poor',
#  'population',
#  'never',
#  'touch',
#  'foreigner',
#  'country',
#  'huge',
#  'foreign',
#  'traveller',
#  'freunde',
#  'die',
#  'pandemie',
#  'ist',
#  'vorbei',
#  'wir',
#  'sind',
#  'alle',
#  'erlöst',
#  'der',
#  'televangelist',
#  'kenneth',
#  'copeland',
#  'hat',
#  'covid19',
#  'verbal',
#  'mal',
#  'richtig',
#  'den',
#  'virenpopo',
#  'getreten',
#  'finished',
#  'corona',
#  'coronavirus',
#  'httpsyoutubeqj6tlhxfteu',
#  'corona',
#  'covid19',
#  'corona',
#  'httpswwwinstagramcompbvft6fjwqmigshid8fyssy4yotim',
#  'cure',
#  'corona',
#  'swear',
#  '’',
#  'gone',
#  'corona',
#  'cure',
#  'mexican',
#  'cure',
#  'httpswwwinstagramcompbvfugwnyyfigshid11wmvktdivnez',
#  'social',
#  'distance',
#  'limiting',
#  'trip',
#  'away',
#  'home',
#  'fill',
#  'drop',
#  'problemsolved',
#  'corona',
#  'gas',
#  'reposted',
#  'manstagram420',
#  'meme',
#  'corona',
#  'memedaily',
#  'funnymemes',
#  'memesdaily',
#  'funnyshit',
#  'httpsfunnyshitfun',
#  'picking',
#  'easter',
#  'outfit',
#  'year',
#  'covid',
#  'corona',
#  'coronavirus',
#  'pajama',
#  'lockdown',
#  'httpswwwinstagramcompbvfvwtpkpkigshidwez12a5m764e',
#  'needed',
#  'easter',
#  'ho',
#  'bad',
#  'nyc',
#  'hoax',
#  'early',
#  'stage',
#  'spreading',
#  'nyc',
#  'alone',
#  '500',
#  'death',
#  'per',
#  'day',
#  'within',
#  '2',
#  'week',
#  'corona',
#  'trumptan',
#  'skandal',
#  'sözler',
#  'ölüm',
#  'sayısını',
#  '200000e',
#  'düşürebilirsek',
#  'harika',
#  'bir',
#  'iş',
#  'çıkarırız',
#  'httpsyeniahvalcomhabertrumptanskandalsozlerolumsayisini200000edusurebilirsekharikabiriscikaririzh11436html',
#  'donaldtrump',
#  'donaldjtrump',
#  'abd',
#  'usa',
#  'usacovid19',
#  'covid19',
#  'covid19',
#  'corona',
#  'coronavirus',
#  'saglik',
#  'coronaviruspandemic',
#  'ver',
#  'jornal',
#  'pra',
#  'passar',
#  'raiva',
#  'com',
#  'o',
#  'pior',
#  'presidente',
#  'e',
#  'mais',
#  'irresponsável',
#  'que',
#  'o',
#  'brasil',
#  'já',
#  'teve',
#  'fantastico',
#  'corona',
#  'desgoverno',
#  'corona',
#  'ne',
#  'saray',
#  'dinledi',
#  'ne',
#  'kraliçe',
#  'ne',
#  'prens',
#  'dinledi',
#  'ne',
#  'prenses',
#  'ne',
#  'başbakan',
#  'ne',
#  'zengin',
#  'ne',
#  'fakir',
#  'ne',
#  'doktor',
#  'ne',
#  'sporcu',
#  'ne',
#  'sanatçı',
#  'ne',
#  'işçi',
#  'ne',
#  'emekçi',
#  'ne',
#  'dinci',
#  'genç',
#  'yaşlı',
#  'büyük',
#  'küçük',
#  'kısacası',
#  'hiç',
#  'kimseyi',
#  'dinlemedi',
#  'bence',
#  'bu',
#  'korona',
#  'sosyali̇st',
#  'herkes',
#  'eşit',
#  'davranıyor',
#  'doğa',
#  'bizlerden',
#  'elbet',
#  'öcünü',
#  'alacaktı',
#  'doğa',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'coronaviruspandemic',
#  'turkey',
#  'italycoronavirus',
#  'chinesevirus19',
#  'usacovid19',
#  'covid19turkey',
#  'covid19out',
#  'covidspain',
#  'covid19italy',
#  'iranfightscorona',
#  'stayathomechallenge',
#  'stayathomesavelives',
#  'step',
#  'week',
#  'neighborhood',
#  'walk',
#  'corona',
#  'nyc',
#  'socialdistance',
#  'walking',
#  'brooklyn',
#  'brooklyn',
#  'new',
#  'york',
#  'httpswwwinstagramcompbvfzcblqvdigshidvb0k2xlfjey3',
#  'arvindkejriwal',
#  'clear',
#  'intention',
#  'risking',
#  'life',
#  'people',
#  'residing',
#  'nda',
#  'led',
#  'govts',
#  'putting',
#  'amp',
#  'bihar',
#  'worst',
#  'risk',
#  'sending',
#  'lac',
#  'people',
#  'discredit',
#  'amp',
#  'push',
#  'bihar',
#  'amp',
#  'ultimately',
#  'india',
#  'worst',
#  'corona',
#  'crisis',
#  '7',
#  'habit',
#  'need',
#  'start',
#  'right',
#  'suspect',
#  'someone',
#  'home',
#  'sick',
#  'httpsbitly3bvg15t',
#  'activerealty',
#  'actvre',
#  'corona',
#  'article',
#  'realestate',
#  'home',
#  'habit',
#  'start',
#  'rightnow',
#  'suspect',
#  'someone',
#  'sick',
#  'temas',
#  'fearnot',
#  'corona',
#  'coronavirus',
#  'covid',
#  'covid19',
#  'covıd19',
#  'httpswwwinstagramcompbvf2cwfmgiigshidpyh4s4nrixan',
#  'mau',
#  'besoksenin',
#  'selasa',
#  'rabu',
#  'kami',
#  'jumat',
#  'sabtu',
#  'minggu',
#  'rebahan',
#  'ya',
#  'rebahan',
#  'nganggur',
#  'ya',
#  'tetap',
#  'nganggur',
#  'corona',
#  'sudah',
#  'lama',
#  'nganggur',
#  'b',
#  'aja',
#  'begitu',
#  'kerja',
#  'hampir',
#  'sedunia',
#  'nganggur',
#  'corona',
#  'coronavirus',
#  'coronakrise',
#  'mundschutz',
#  'maske',
#  'maskeauf',
#  'verkehrtewelt',
#  'jij',
#  'kan',
#  'het',
#  'verschil',
#  'maken',
#  'saman',
#  'tegen',
#  'het',
#  'corona',
#  'virus',
#  'zo',
#  'spontaan',
#  'en',
#  'puur',
#  'beauvaned',
#  'deze',
#  'aandacht',
#  'super',
#  'en',
#  'dit',
#  'doe',
#  'je',
#  'goed',
#  'rtl4',
#  'beaublijftthuis',
#  'beaublijftbinnen',
#  'covid19',
#  'transplantatie',
#  'jamai',
#  'zo',
#  'herkenbaar',
#  'im',
#  'raising',
#  'money',
#  'help',
#  'family',
#  'survive',
#  'uncle',
#  'laid',
#  'aunt',
#  'disabled',
#  'need',
#  'help',
#  'grocery',
#  'bill',
#  'money',
#  'httpgfmeuxjvrn6',
#  'covid19',
#  'sundayvibes',
#  'corona',
#  'sundaythoughts',
#  'quarentinelife',
#  'help',
#  'stayathomeandstaysafe',
#  'lockdown',
#  'cashapp',
#  'pulte',
#  'q',
#  'usa',
#  'young',
#  'people',
#  'seem',
#  'die',
#  'corona',
#  'drbirx',
#  'really',
#  'say',
#  'population',
#  'usa',
#  '7',
#  '9',
#  'percent',
#  'younger',
#  'population',
#  'europe',
#  'maybe',
#  'drbirx',
#  'youth',
#  'usa',
#  'least',
#  '7',
#  '9',
#  'percent',
#  'obese',
#  'well',
#  'trumppressconf',
#  'xi',
#  'jinping',
#  '‘',
#  'itna',
#  'acche',
#  'se',
#  'corona',
#  'kaise',
#  'faila',
#  'diya',
#  'tumne',
#  '’',
#  'le',
#  'kejriwal',
#  'believe',
#  '100k',
#  'could',
#  'die',
#  'usa',
#  'yes',
#  'unconditionally',
#  'b',
#  'yes',
#  'head',
#  'heart',
#  'c',
#  'trump',
#  'd',
#  'liberaldem',
#  'hoax',
#  'china',
#  'cnnelection',
#  'cnntownhall',
#  'cnnsotu',
#  'cnn',
#  'nbc',
#  'abcnews',
#  'coronavirus',
#  'corona',
#  'coronavirus',
#  'coronacrisis',
#  'returning',
#  'toilet',
#  'paper',
#  'costco',
#  'lol',
#  'corona',
#  'humor',
#  'funnymemes',
#  'funnyshit',
#  'funnyquotes',
#  'costco',
#  'sandiego',
#  'san',
#  'httpswwwinstagramcompbvf7rqjnhvigshid36iecwwsfuq3',
#  'acoustic',
#  'live',
#  'music',
#  'quarantine',
#  'acousticguitar',
#  'acoustic',
#  'live',
#  'livestream',
#  'music',
#  'acousticmusic',
#  'looper',
#  'solo',
#  'guitarsolo',
#  'guitarist',
#  'singer',
#  'songwriter',
#  'musician',
#  'ditto',
#  'guitarplayer',
#  'corona…',
#  'httpswwwinstagramcompbvf3esjatmigshid16exgdle7j4of',
#  'probably',
#  'seemed',
#  'like',
#  'good',
#  'idea',
#  'theory',
#  'imagine',
#  'powerrangers',
#  'comedy',
#  'celebrity',
#  'covid19',
#  'corona',
#  'coronavirusmemes',
#  'quarantine',
#  'funnymemes',
#  'bebetter',
#  '“',
#  'one',
#  'call',
#  'chicken',
#  'cave',
#  '”',
#  'anchorman',
#  'champ',
#  'fried',
#  'bat',
#  'corona',
#  'virus',
#  '2020',
#  'httpswwwinstagramcompbvf94glwvwigshidfsd6hrwcwg1',
#  'saurabhtop',
#  'sardesairajdeep',
#  'check',
#  'httpsflattenca',
#  'similar',
#  'self',
#  'assesment',
#  'tool',
#  'introduce',
#  'service',
#  'provider',
#  'reliancejio',
#  'airtelindia',
#  'vodafonein',
#  'india',
#  'concept',
#  'use',
#  'identify',
#  'track',
#  'corona',
#  'infected',
#  'people',
#  'community',
#  'indiafightscorona',
#  'nou',
#  'ja',
#  'ka',
#  'goumin',
#  'contre',
#  'en',
#  'virus',
#  'mais',
#  'fok',
#  'aussi',
#  'nou',
#  'goumin',
#  'contre',
#  'cochon',
#  'arrêter',
#  'un',
#  'peu',
#  'cestquoisa',
#  'corona',
#  'malpropre',
#  'httpswwwinstagramcompbvfox7ji4igshid1e8ke9u3raehd',
#  'think',
#  '’',
#  'll',
#  'see',
#  'alien',
#  'visit',
#  'earth',
#  'next',
#  '2020',
#  'movie',
#  'genre',
#  'genre',
#  'genre',
#  'guess',
#  'one',
#  '’',
#  've',
#  'already',
#  'coronavirus',
#  'corona',
#  'covid19',
#  'corona',
#  'covid19',
#  'bazı',
#  'tavsiyeler',
#  'korona',
#  'bilmem',
#  'kaç',
#  'yüz',
#  'tane',
#  'hayvan',
#  'hücresi',
#  'boyutundadır',
#  'normal',
#  'virüslerden',
#  'oldukça',
#  'büyük',
#  'şişkoluğundan',
#  'dolayı',
#  'havada',
#  'fazlaca',
#  'asılı',
#  'kalamaz',
#  've',
#  'aşağı',
#  'düşer',
#  'bu',
#  'sebeple',
#  'dışarıdan',
#  'eve',
#  'geldiğinizde',
#  'ayakkabılarınızı',
#  'da',
#  'dezenfekte',
#  'etmenizi',
#  'öneririm',
#  'ahlak',
#  'namazı',
#  'bitene',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'riya',
#  'orucu',
#  'tutana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'tağşiş',
#  'malı',
#  'satana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'söze',
#  'yalan',
#  'katana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'haram',
#  'yerde',
#  'yatana',
#  'ne',
#  'söyler',
#  'ki',
#  'corona',
#  'yeğrenî',
#  'kul',
#  'böyle',
#  'der',
#  'i̇nanmazsan',
#  'sor',
#  'ona',
#  'keine',
#  'macht',
#  'den',
#  'dilettanten',
#  'gut',
#  'das',
#  'die',
#  'bundesregierung',
#  'auf',
#  'drosten',
#  'kekulé',
#  'und',
#  'andere',
#  'wahre',
#  'experten',
#  'hört',
#  'ökotyrannei',
#  'covid19',
#  'corona',
#  'repost',
#  'cantarafoundation',
#  '•',
#  '•',
#  '•',
#  '•',
#  '•',
#  'stayhome',
#  'dengan',
#  'dirumahaja',
#  'kita',
#  'sudah',
#  'berkontribusi',
#  'untuk',
#  'memutus',
#  'mata',
#  'rantai',
#  'penyebaran',
#  'virus',
#  'corona',
#  'covid19',
#  'dirumahaja',
#  'corona',
#  'virus…',
#  'httpswwwinstagramcompbvge2jaqsfjbrobscsq5equfugcpu7cvo0igshidvasfzm3bi2e4',
#  'bodycon',
#  'mesh',
#  'dress',
#  'httpswwwwestoutfitcomshopbodyconmeshdress',
#  'westoutfit',
#  'dress',
#  'dress',
#  '20',
#  'free',
#  'ship',
#  'return',
#  'covid',
#  'sale',
#  'girl',
#  'girl',
#  'gurl',
#  'woman',
#  'womendress',
#  'usa',
#  'world',
#  'corona',
#  'dressstore',
#  'shopping',
#  'rough',
#  'quarantine',
#  'eat',
#  'freezer',
#  'grilling',
#  'quarantine',
#  'covid19',
#  'corona',
#  'httpswwwinstagramcompbvgf2hpehyigshid1hz8zlajlot13',
#  'httpsyenicizgihabercomhaberabdicinkorkutansenaryohaberi143951html',
#  'vaka9217',
#  'amerika',
#  'korona',
#  'corona',
#  'usa',
#  'covid19turkey',
#  'sondakika',
#  'haber',
#  'people',
#  'put',
#  'quarantine',
#  'italy',
#  'broke',
#  'outfast',
#  'foward',
#  'week',
#  'later',
#  'italy',
#  'top',
#  'world',
#  'death',
#  'toll',
#  'people',
#  'eldoret',
#  'defied',
#  'stay',
#  'home',
#  'order',
#  '1',
#  'death',
#  'already',
#  'kenyan',
#  'still',
#  'dont',
#  'take',
#  'corona',
#  'seriously',
#  'smh',
#  'thing',
#  'get',
#  'better',
#  'covid19',
#  'corona',
#  'httpwwwbenefitmankindcouk',
#  'stayathomeandstaysafe',
#  'new',
#  'podcast',
#  'café',
#  'com',
#  'rocknroll',
#  'spreaker',
#  'carreiraprofissional',
#  'corona',
#  'economia',
#  'empreendedorismo',
#  'voce',
#  'lockdown',
#  '’',
#  'important',
#  'remember',
#  'local',
#  'small',
#  'business',
#  'whether',
#  '’',
#  'coffee',
#  'shop',
#  'restaurant',
#  'bookstore',
#  'encourage',
#  'look',
#  'drive',
#  'option',
#  'area',
#  'support',
#  'small',
#  'business',
#  'smallbuisnesssunday',
#  'corona',
#  'supportsmallbusiness',
#  'dünyanın',
#  'kötü',
#  'bir',
#  'yer',
#  'olduğunu',
#  'söyler',
#  'dururduk',
#  'şimdi',
#  'o',
#  'kötü',
#  'dünyaya',
#  'muhtacız',
#  'corona',
#  'escape',
#  'new',
#  'york',
#  'shelter',
#  'place',
#  'nh',
#  'live',
#  'free',
#  '’',
#  'die',
#  'corona',
#  'covid19',
#  'escapefromnewyork',
#  'livefreeanddontdie',
#  'amherstnh',
#  'amherst',
#  'new',
#  'hampshire',
#  'httpswwwinstagramcompbvfoi2adczigshid1amv9c46mbui6',
#  'günlük',
#  'burç',
#  'yorumları',
#  '28',
#  'mart',
#  ...]

# %%
newemotion_list
# Out:
# [' attracted',
#  ' angry',
#  ' attracted',
#  ' attached',
#  ' fearless',
#  ' bored',
#  ' fearless',
#  ' average',
#  ' surprise',
#  ' powerless',
#  ' angry',
#  ' demoralized',
#  ' happy',
#  ' powerless',
#  ' free',
#  ' fearful',
#  ' hated',
#  ' happy',
#  ' apathetic',
#  ' lost',
#  ' sad',
#  ' happy',
#  ' powerless',
#  ' adequate',
#  ' sad',
#  ' fearful',
#  ' sad',
#  ' sad',
#  ' powerless',
#  ' alone',
#  ' average',
#  ' adequate',
#  ' happy',
#  ' happy',
#  ' sad',
#  ' esteemed']

# %%
newemotion_list = []
with open('emotions.txt', 'r') as file:
    for line in file:
        newclear_line = line.replace('\n', '').replace(',', '').replace("'", '').strip()
        word, emotion = newclear_line.split(':')
        if word in newlemma_words:
            newemotion_list.append(emotion)
print("People emotions from the text \n", newemotion_list, '\n \n')

nw = Counter(newemotion_list)
print("Count of each emotion \n", nw)
# Out:
# People emotions from the text
#  [' attracted', ' angry', ' attracted', ' attached', ' fearless', ' bored', ' fearless', ' average', ' surprise', ' powerless', ' angry', ' demoralized', ' happy', ' powerless', ' free', ' fearful', ' hated', ' happy', ' apathetic', ' lost', ' sad', ' happy', ' powerless', ' adequate', ' sad', ' fearful', ' sad', ' sad', ' powerless', ' alone', ' average', ' adequate', ' happy', ' happy', ' sad', ' esteemed']
#
#
# Count of each emotion
#  Counter({' happy': 5, ' sad': 5, ' powerless': 4, ' attracted': 2, ' angry': 2, ' fearless': 2, ' average': 2, ' fearful': 2, ' adequate': 2, ' attached': 1, ' bored': 1, ' surprise': 1, ' demoralized': 1, ' free': 1, ' hated': 1, ' apathetic': 1, ' lost': 1, ' alone': 1, ' esteemed': 1})

# %%
fig, ax1 = plt.subplots(figsize=(10,15))
ax1.bar(nw.keys(), nw.values())
fig.autofmt_xdate()
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# # lets take two documents doc_a and doc_b (few lines choosen from above data (twitter))(bag of words using count vectorizer)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Single document (',' seperates each document)
doc_a = ["during this global pandemic,one of the most important ways to prevent the spread of coronavirus is to wash your hands frequently with soap and water and wear a mask when you step outside.Together we all can fight against covid19"]

# This step will convert text into tokens 
vect1 = CountVectorizer()

vect1.fit_transform(doc_a)
print("bag of words :",vect1.get_feature_names())
# Out:
# bag of words : ['against', 'all', 'and', 'can', 'coronavirus', 'covid19', 'during', 'fight', 'frequently', 'global', 'hands', 'important', 'is', 'mask', 'most', 'of', 'one', 'outside', 'pandemic', 'prevent', 'soap', 'spread', 'step', 'the', 'this', 'to', 'together', 'wash', 'water', 'ways', 'we', 'wear', 'when', 'with', 'you', 'your']

# %%
vect1.vocabulary_
# Out:
# {'during': 6,
#  'this': 24,
#  'global': 9,
#  'pandemic': 18,
#  'one': 16,
#  'of': 15,
#  'the': 23,
#  'most': 14,
#  'important': 11,
#  'ways': 29,
#  'to': 25,
#  'prevent': 19,
#  'spread': 21,
#  'coronavirus': 4,
#  'is': 12,
#  'wash': 27,
#  'your': 35,
#  'hands': 10,
#  'frequently': 8,
#  'with': 33,
#  'soap': 20,
#  'and': 2,
#  'water': 28,
#  'wear': 31,
#  'mask': 13,
#  'when': 32,
#  'you': 34,
#  'step': 22,
#  'outside': 17,
#  'together': 26,
#  'we': 30,
#  'all': 1,
#  'can': 3,
#  'fight': 7,
#  'against': 0,
#  'covid19': 5}

# %%
count_vect = CountVectorizer()

count_vect.fit(doc_a)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
doc_b = ['I guess the biggest success we have this week,is finally putting all our cover safety measures together for unseen tours in tough times like covid19,so that we can start preparing for safe and enjoyable events in london safety first!The safety of our employees,customers and suppliers are our top priority.Face mask,hand washing,disinfecting,social distancing.We are in this together']

count_new_vect = count_vect.transform(doc_b)

print ("Text Present at ",count_new_vect.toarray())

# Compare with the indexes
print ("original indexes", vect1.get_feature_names() )
#we can see presence of words from doc_b in bag of words of doc_a 
#such as "we" is present 3 times,
#"all" is present is 1 time,"and" is present 3 times,
#"together" is present 2 times,"is" present 1 time,"mask" present 1 time,"covid19" present 1 time,
#"this" present 2 times,"together" present 2 times,"the" present 2 times,"of" present 1 time
#11 words present from doc_b in bog of words of doc_a
# Out:
# Text Present at  [[0 1 2 1 0 1 0 0 0 0 0 0 1 1 0 1 0 0 0 0 0 0 0 2 2 0 2 0 0 0 3 0 0 0 0 0]]
# original indexes ['against', 'all', 'and', 'can', 'coronavirus', 'covid19', 'during', 'fight', 'frequently', 'global', 'hands', 'important', 'is', 'mask', 'most', 'of', 'one', 'outside', 'pandemic', 'prevent', 'soap', 'spread', 'step', 'the', 'this', 'to', 'together', 'wash', 'water', 'ways', 'we', 'wear', 'when', 'with', 'you', 'your']
